# %%
from matplotlib.pyplot import figure
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from pandas import DataFrame
from plotly.subplots import make_subplots
import pandas as pd  
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
# %matplotlib inline

#convert .xls to .csv
df = pd.read_excel('/home/emma/education_data_science/bachelors_degree.xls', sheet_name=None)
df['Education 1970 to 2017'].to_csv('bs_degrees.csv')

# %%
#Read csv file and load to bachelors_degree_data  data frame

bachelors_degree_data = pd.read_csv("/home/emma/education_data_science/bs_degrees.csv")

# %%
bachelors_degree_data
# Out:
#       Unnamed: 0  FIPS Code State                Area name  \
# 0              0          0    US            United States
# 1              1       1000    AL                  Alabama
# 2              2       1001    AL           Autauga County
# 3              3       1003    AL           Baldwin County
# 4              4       1005    AL           Barbour County
# 5              5       1007    AL              Bibb County
# 6              6       1009    AL            Blount County
# 7              7       1011    AL           Bullock County
# 8              8       1013    AL            Butler County
# 9              9       1015    AL           Calhoun County
# 10            10       1017    AL          Chambers County
# 11            11       1019    AL          Cherokee County
# 12            12       1021    AL           Chilton County
# 13            13       1023    AL           Choctaw County
# 14            14       1025    AL            Clarke County
# ...

# %%
graph_presentation = px.bar(bachelors_degree_data, x = 'State', y = "Bachelor's degree or higher, 1990", title='Bachelor degree holders 1990')
graph_presentation.show()
# Out:
# <div>
#
#
#             <div id="54696a62-ff34-4d29-83ea-362ca8aa0ea9" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("54696a62-ff34-4d29-83ea-362ca8aa0ea9")) {
#                     Plotly.newPlot(
#                         '54696a62-ff34-4d29-83ea-362ca8aa0ea9',
# ...

# %%
bachelors_degree_data["Bachelor's degree or higher, 1990"].hist(bins=50)

# %%
bachelors_degree_data["Bachelor's degree or higher, 2000"].hist(bins=50)

# %%
bachelors_degree_data["Bachelor's degree or higher, 2013-17"].hist(bins=50)

# %%
#check the number of rows and columns
print("Number of rows and columns", bachelors_degree_data.shape)
# Out:
# Number of rows and columns (3283, 7)

# %%
bachelors_degree_data["State"].value_counts()
# Out:
# TX    255
# GA    160
# VA    136
# KY    121
# MO    116
# KS    106
# IL    103
# NC    101
# IA    100
# TN     96
# NE     94
# IN     93
# OH     89
# MN     88
# MI     84
# MS     83
# PR     79
# OK     78
# AR     76
# WI     73
# PA     68
# FL     68
# AL     68
# SD     67
# LA     65
# CO     65
# NY     63
# CA     59
# MT     58
# WV     56
# ND     54
# SC     47
# ID     45
# WA     40
# OR     37
# AK     37
# NM     34
# UT     30
# MD     25
# WY     24
# NJ     22
# NV     18
# ME     17
# AZ     16
# VT     15
# MA     15
# NH     11
# CT      9
# HI      6
# RI      6
# DE      4
# DC      2
# US      1
# Name: State, dtype: int64

# %%
bachelors_degree_data["Area name"].value_counts()
# Out:
# Washington County          30
# Jefferson County           25
# Franklin County            24
# Jackson County             23
# Lincoln County             23
# Madison County             19
# Clay County                18
# Montgomery County          18
# Union County               17
# Monroe County              17
# Marion County              17
# Wayne County               16
# Grant County               14
# Warren County              14
# Greene County              14
# Carroll County             13
# Polk County                12
# Lee County                 12
# Clark County               12
# Johnson County             12
# Adams County               12
# Lake County                12
# Douglas County             12
# Marshall County            12
# Lawrence County            11
# Crawford County            11
# Calhoun County             11
# Scott County               11
# Morgan County              11
# Fayette County             11
#                            ..
# ...

# %%
bachelors_degree_data[bachelors_degree_data['Area name'] == 'Washington County']
# Out:
#       Unnamed: 0  FIPS Code State          Area name  \
# 66            66       1129    AL  Washington County
# 194          194       5143    AR  Washington County
# 319          319       8121    CO  Washington County
# 404          404      12133    FL  Washington County
# 555          555      13303    GA  Washington County
# 615          615      16087    ID  Washington County
# 711          711      17189    IL  Washington County
# 807          807      18175    IN  Washington County
# 904          904      19183    IA  Washington County
# 1013        1013      20201    KS  Washington County
# 1133        1133      21229    KY  Washington County
# 1219        1219      23029    ME  Washington County
# 1242        1242      24043    MD  Washington County
# 1427        1427      27163    MN  Washington County
# 1509        1509      28151    MS  Washington County
# 1626        1626      29221    MO  Washington County
# 1779        1779      31177    NE  Washington County
# ...

# %%
bachelors_degree_data[bachelors_degree_data['State'] == 'TX']
# Out:
#       Unnamed: 0  FIPS Code State          Area name  \
# 2575        2575      48000    TX              Texas
# 2576        2576      48001    TX    Anderson County
# 2577        2577      48003    TX     Andrews County
# 2578        2578      48005    TX    Angelina County
# 2579        2579      48007    TX     Aransas County
# 2580        2580      48009    TX      Archer County
# 2581        2581      48011    TX   Armstrong County
# 2582        2582      48013    TX    Atascosa County
# 2583        2583      48015    TX      Austin County
# 2584        2584      48017    TX      Bailey County
# 2585        2585      48019    TX     Bandera County
# 2586        2586      48021    TX     Bastrop County
# 2587        2587      48023    TX      Baylor County
# 2588        2588      48025    TX         Bee County
# 2589        2589      48027    TX        Bell County
# 2590        2590      48029    TX       Bexar County
# 2591        2591      48031    TX      Blanco County
# ...

# %%
bachelors_degree_data
# Out:
#       Unnamed: 0  FIPS Code State                Area name  \
# 0              0          0    US            United States
# 1              1       1000    AL                  Alabama
# 2              2       1001    AL           Autauga County
# 3              3       1003    AL           Baldwin County
# 4              4       1005    AL           Barbour County
# 5              5       1007    AL              Bibb County
# 6              6       1009    AL            Blount County
# 7              7       1011    AL           Bullock County
# 8              8       1013    AL            Butler County
# 9              9       1015    AL           Calhoun County
# 10            10       1017    AL          Chambers County
# 11            11       1019    AL          Cherokee County
# 12            12       1021    AL           Chilton County
# 13            13       1023    AL           Choctaw County
# 14            14       1025    AL            Clarke County
# ...

# %%
bachelors_degree_data["State"].value_counts()
# Out:
# TX    255
# GA    160
# VA    136
# KY    121
# MO    116
# KS    106
# IL    103
# NC    101
# IA    100
# TN     96
# NE     94
# IN     93
# OH     89
# MN     88
# MI     84
# MS     83
# PR     79
# OK     78
# AR     76
# WI     73
# PA     68
# FL     68
# AL     68
# SD     67
# LA     65
# CO     65
# NY     63
# CA     59
# MT     58
# WV     56
# ND     54
# SC     47
# ID     45
# WA     40
# OR     37
# AK     37
# NM     34
# UT     30
# MD     25
# WY     24
# NJ     22
# NV     18
# ME     17
# AZ     16
# VT     15
# MA     15
# NH     11
# CT      9
# HI      6
# RI      6
# DE      4
# DC      2
# US      1
# Name: State, dtype: int64

# %%
x = bachelors_degree_data["State"].value_counts()
print(x.count())
# Out:
# 53

# %%
""" Notice Area name and state
    The actual state value has a summation of all county info
    AL - Alabama has all info in all counties tagged AL
"""

bachelors_degree_data
# Out:
#       Unnamed: 0  FIPS Code State                Area name  \
# 0              0          0    US            United States
# 1              1       1000    AL                  Alabama
# 2              2       1001    AL           Autauga County
# 3              3       1003    AL           Baldwin County
# 4              4       1005    AL           Barbour County
# 5              5       1007    AL              Bibb County
# 6              6       1009    AL            Blount County
# 7              7       1011    AL           Bullock County
# 8              8       1013    AL            Butler County
# 9              9       1015    AL           Calhoun County
# 10            10       1017    AL          Chambers County
# 11            11       1019    AL          Cherokee County
# 12            12       1021    AL           Chilton County
# 13            13       1023    AL           Choctaw County
# 14            14       1025    AL            Clarke County
# ...

# %%
bachelors_degree_data.loc[bachelors_degree_data['State'] == 'AL', "Bachelor's degree or higher, 1990"].sum()
# Out:
# 798456.0

# %%
Alabama = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 1000]

# %%
Alabama
# Out:
#    Unnamed: 0  FIPS Code State Area name  Bachelor's degree or higher, 1990  \
# 1           1       1000    AL   Alabama                           399228.0
#
#    Bachelor's degree or higher, 2000  Bachelor's degree or higher, 2013-17
# 1                           549608.0                              803578.0

# %%
#Create data frames based on FIPS Code

Alaska = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 2000]
AZ = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 4000]
AR = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 5000]
CA = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 6000]
CO = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 8000]
CT = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 9000]
DE = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 10000]
FL = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 12000]
GA = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 13000]
HI = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 15000]
ID = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 16000]
IL = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 17000]
IN = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 18000]
IA = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 19000]
KS = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 20000]
KY = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 21000]
LA = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 22000]
ME = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 23000]
MD = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 24000]
MA = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 25000]
WY = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 56000]
MI = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 26000]

MN = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 27000]
MS = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 28000]
MO = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 29000]
MT = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 30000]
NE = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 31000]
NV = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 32000]
NH = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 33000]
NJ = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 34000]
NM = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 35000]
NY = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 36000]
NC = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 37000]
ND = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 38000]
OH = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 39000]
OK = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 40000]
OR = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 41000]
PA = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 42000]
RI = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 44000]
SC = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 45000]
SD = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 46000]
TN = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 47000]
TX = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 48000]
UT = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 49000]

VT = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 50000]
VA = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 51000]
WA = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 53000]
WV = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 54000]
WI = bachelors_degree_data[bachelors_degree_data['FIPS Code'] == 55000]


states_table = pd.concat([Alabama, Alaska])

# %%
states_table
# Out:
#     Unnamed: 0  FIPS Code State Area name  Bachelor's degree or higher, 1990  \
# 1            1       1000    AL   Alabama                           399228.0
# 69          69       2000    AK    Alaska                            74497.0
#
#     Bachelor's degree or higher, 2000  Bachelor's degree or higher, 2013-17
# 1                            549608.0                              803578.0
# 69                            93807.0                              137821.0

# %%
""" Merge all data frames to get states """

states_data_frame = pd.concat([Alabama, Alaska, AZ, AR, CA,CO, CT, DE, FL, GA,HI, ID, IL, IN, IA, KS, KY,LA, ME, MD, 
                               MA, WY, MI, MN, MS, MO, MT, NE, NV, NH, NJ, NM, NY, NC, ND, OH, OK, OR, PA, RI, SC, 
                               SD, TN, TX, UT, VT, VA, WA, WV, WI])

# %%
states_data_frame
# Out:
#       Unnamed: 0  FIPS Code State       Area name  \
# 1              1       1000    AL         Alabama
# 69            69       2000    AK          Alaska
# 106          106       4000    AZ         Arizona
# 122          122       5000    AR        Arkansas
# 198          198       6000    CA      California
# 257          257       8000    CO        Colorado
# 322          322       9000    CT     Connecticut
# 331          331      10000    DE        Delaware
# 337          337      12000    FL         Florida
# 405          405      13000    GA         Georgia
# 565          565      15000    HI          Hawaii
# 571          571      16000    ID           Idaho
# 616          616      17000    IL        Illinois
# 719          719      18000    IN         Indiana
# 812          812      19000    IA            Iowa
# 912          912      20000    KS          Kansas
# 1018        1018      21000    KY        Kentucky
# 1139        1139      22000    LA        Lousiana
# ...

# %%
graph_1990 = px.line(states_data_frame, x = 'State', y = "Bachelor's degree or higher, 1990", title='Bachelor degree holders 1990')
graph_1990.show()
# Out:
# <div>
#
#
#             <div id="79bf3aef-c168-46cd-87a7-1938ad9efcb5" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("79bf3aef-c168-46cd-87a7-1938ad9efcb5")) {
#                     Plotly.newPlot(
#                         '79bf3aef-c168-46cd-87a7-1938ad9efcb5',
# ...

# %%
graph_2000 = px.line(states_data_frame, x = 'State', y = "Bachelor's degree or higher, 2000", title='Bachelor degree holders 2000')
graph_2000.show()
# Out:
# <div>
#
#
#             <div id="f312c012-22df-457a-9d87-e706fb8ed4f3" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f312c012-22df-457a-9d87-e706fb8ed4f3")) {
#                     Plotly.newPlot(
#                         'f312c012-22df-457a-9d87-e706fb8ed4f3',
# ...

# %%
graph_2013_17 = px.line(states_data_frame, x = 'State', y = "Bachelor's degree or higher, 2013-17", title='Bachelor degree holders 2013-17')
graph_2013_17.show()
# Out:
# <div>
#
#
#             <div id="5a5ddb55-22d5-490d-9a0e-29c40295fea5" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5a5ddb55-22d5-490d-9a0e-29c40295fea5")) {
#                     Plotly.newPlot(
#                         '5a5ddb55-22d5-490d-9a0e-29c40295fea5',
# ...

# %%
states_data_frame.to_csv('/home/emma/education_data_science/states_data.csv', index=False)

# %%
state = states_data_frame["State"]
bachelors_2013_17 = states_data_frame["Bachelor's degree or higher, 2013-17"]
bachelors_2000 = states_data_frame["Bachelor's degree or higher, 2000"]
bachelors_1990 = states_data_frame["Bachelor's degree or higher, 1990"]

trace0 = go.Scatter(
    x = state,
    y = bachelors_1990,
    mode = "lines",
    name = "Bachelor's degree or higher 1990"
)

trace1 = go.Scatter(
    x = state,
    y = bachelors_2000,
    mode = "lines",
    name = "Bachelor's degree or higher 2000"
)

trace2 = go.Scatter(
    x = state,
    y = bachelors_2013_17,
    mode = "lines",
    name = "Bachelor's degree or higher 2013_17"
)

# %%
data = [trace0, trace1, trace2]

# %%
layout = go.Layout(
    title = "Bachelor's degree or higher 1990 - 2017",
     xaxis=dict(
        title='US States',
        tickmode='linear'),
     yaxis=dict(
        title='Bachelor degree or higher')
        
)
fig = go.Figure(data = data, layout = layout)
fig.show()
# Out:
# <div>
#
#
#             <div id="ab51c157-c207-4185-b3a3-125d27829b6f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ab51c157-c207-4185-b3a3-125d27829b6f")) {
#                     Plotly.newPlot(
#                         'ab51c157-c207-4185-b3a3-125d27829b6f',
# ...

# %%
bachelors_degree_data.describe()
# Out:
#         Unnamed: 0     FIPS Code  Bachelor's degree or higher, 1990  \
# count  3283.000000   3283.000000                       3.271000e+03
# mean   1641.000000  31308.242766                       2.980365e+04
# std     947.864793  16343.477485                       5.791890e+05
# min       0.000000      0.000000                       0.000000e+00
# 25%     820.500000  19016.000000                       6.740000e+02
# 50%    1641.000000  30017.000000                       1.567000e+03
# 75%    2461.500000  46100.000000                       5.043000e+03
# max    3282.000000  72153.000000                       3.231025e+07
#
#        Bachelor's degree or higher, 2000  Bachelor's degree or higher, 2013-17
# count                       3.272000e+03                          3.273000e+03
# mean                        4.097939e+04                          6.167258e+04
# std                         7.958172e+05                          1.196957e+06
# ...

# %%
states_data_frame.head()
# Out:
#      Unnamed: 0  FIPS Code State   Area name  \
# 1             1       1000    AL     Alabama
# 69           69       2000    AK      Alaska
# 106         106       4000    AZ     Arizona
# 122         122       5000    AR    Arkansas
# 198         198       6000    CA  California
#
#      Bachelor's degree or higher, 1990  Bachelor's degree or higher, 2000  \
# 1                             399228.0                           549608.0
# 69                             74497.0                            93807.0
# 106                           466873.0                           766212.0
# 122                           199304.0                           288428.0
# 198                          4366674.0                          5669966.0
#
#      Bachelor's degree or higher, 2013-17
# 1                                803578.0
# 69                               137821.0
# 106                             1284657.0
# 122                              437428.0
# ...

# %%
Califonia = DataFrame({"Year":[1990, 2000, 2017], "Bs Degree or Higher":[4366674, 5669966, 8453731]})

# %%
Califonia
# Out:
#    Year  Bs Degree or Higher
# 0  1990              4366674
# 1  2000              5669966
# 2  2017              8453731

# %%
Califonia.to_csv('/home/emma/education_data_science/califonia.csv', index=False)

# %%
califonia_data = pd.read_csv("/home/emma/education_data_science/califonia.csv")

# %%
califonia_data
# Out:
#    Year  Bs Degree or Higher
# 0  1990              4366674
# 1  2000              5669966
# 2  2017              8453731

# %%
X = califonia_data.iloc[:, 0].values.reshape(-1, 1)  # values converts it into a numpy array
Y = califonia_data.iloc[:, 1].values.reshape(-1, 1)  # -1 means that calculate the dimension of rows, but have 1 column
linear_regressor = LinearRegression()  # create object for the class
linear_regressor.fit(X, Y)  # perform linear regression
Y_pred = linear_regressor.predict(X)  # make predictions

# %%
plt.scatter(X, Y)
plt.plot(X, Y_pred, color='red')
plt.show()

# %%
x = califonia_data.iloc[:, 0].values.reshape(-1, 1)
y = califonia_data.iloc[:, 1].values.reshape(-1, 1)

# Split the dataset into the training set and test set
# We're splitting the data in 1/3, so out of 30 rows, 20 rows will go into the training set,
# and 10 rows will go into the testing set.
xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size = 1/3, random_state = 0)

#Create a linear regression object
linearRegressor = LinearRegression()

#Train the model
linearRegressor.fit(xTrain, yTrain)
#Test the model
yPrediction = linearRegressor.predict(xTest)

# %%
plt.scatter(xTrain, yTrain, color = 'red')
plt.plot(xTrain, linearRegressor.predict(xTrain), color = 'blue')
plt.title('Popln with Bs Degree or higher vs Years')
plt.xlabel('Year')
plt.ylabel('No. with Bs Degree or Higher')
plt.show()

# %%
plt.scatter(xTest, yTest, color = 'red')
plt.plot(xTrain, linearRegressor.predict(xTrain), color = 'blue')
plt.title('Popln with Bs Degree or higher vs Years')
plt.xlabel('Year')
plt.ylabel('No. with Bs Degree or Higher')
plt.show()

# %%
states_data_frame
# Out:
#       Unnamed: 0  FIPS Code State       Area name  \
# 1              1       1000    AL         Alabama
# 69            69       2000    AK          Alaska
# 106          106       4000    AZ         Arizona
# 122          122       5000    AR        Arkansas
# 198          198       6000    CA      California
# 257          257       8000    CO        Colorado
# 322          322       9000    CT     Connecticut
# 331          331      10000    DE        Delaware
# 337          337      12000    FL         Florida
# 405          405      13000    GA         Georgia
# 565          565      15000    HI          Hawaii
# 571          571      16000    ID           Idaho
# 616          616      17000    IL        Illinois
# 719          719      18000    IN         Indiana
# 812          812      19000    IA            Iowa
# 912          912      20000    KS          Kansas
# 1018        1018      21000    KY        Kentucky
# 1139        1139      22000    LA        Lousiana
# ...

# %%
states_data_frame['text'] = "Bs Degree or higher 2013-17"+"\
    "+ states_data_frame["Bachelor's degree or higher, 2013-17"].astype(str) + " " +"State:" +" \
    "+ states_data_frame["Area name"]

fig = go.Figure(data=go.Choropleth(
    locations=states_data_frame['State'], # Spatial coordinates
    z = states_data_frame["Bachelor's degree or higher, 2013-17"].astype(float), # Data to be color-coded
    locationmode = 'USA-states', # set of locations match entries in `locations`
    colorscale = 'Blues',
    text = states_data_frame['text'],
    colorbar_title = "Bachelor's degree or higher",
))


fig.update_layout(
    title_text= "Bachelor's degree or higher 2013-17",
    geo = dict(
        scope='usa',
        projection=go.layout.geo.Projection(type = 'albers usa'),
        showlakes=True, # lakes
        lakecolor='rgb(255,255,255)'),
)

fig.show()
# Out:
# <div>
#
#
#             <div id="0d23430e-a009-49d8-9ba8-3c92d744e657" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0d23430e-a009-49d8-9ba8-3c92d744e657")) {
#                     Plotly.newPlot(
#                         '0d23430e-a009-49d8-9ba8-3c92d744e657',
# ...
