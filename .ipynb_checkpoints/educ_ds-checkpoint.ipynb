# %%
import pandas as pd
df = pd.read_excel('/home/emma/education_data_science/Education.xls', sheet_name=None)
df['Education 1970 to 2017'].to_csv('educ_data.csv')

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

#makes visualization within the notebook
# %matplotlib inline 

#reading the dataset in a dataframe using pandas
educ_data_frame = pd.read_csv('/home/emma/education_data_science/educ_data.csv')

# %%
#print out the data frame
educ_data_frame
# Out:
#          3  FIPS Code State                Area name  \
# 0        4          0    US            United States
# 1        5       1000    AL                  Alabama
# 2        6       1001    AL           Autauga County
# 3        7       1003    AL           Baldwin County
# 4        8       1005    AL           Barbour County
# 5        9       1007    AL              Bibb County
# 6       10       1009    AL            Blount County
# 7       11       1011    AL           Bullock County
# 8       12       1013    AL            Butler County
# 9       13       1015    AL           Calhoun County
# 10      14       1017    AL          Chambers County
# 11      15       1019    AL          Cherokee County
# 12      16       1021    AL           Chilton County
# 13      17       1023    AL           Choctaw County
# 14      18       1025    AL            Clarke County
# 15      19       1027    AL              Clay County
# 16      20       1029    AL          Cleburne County
# ...

# %%
#print out the first 5 rows from the data frame
educ_data_frame.head()
# Out:
#    3  FIPS Code State       Area name  2003 Rural-urban Continuum Code  \
# 0  4          0    US   United States                              NaN
# 1  5       1000    AL         Alabama                              NaN
# 2  6       1001    AL  Autauga County                              2.0
# 3  7       1003    AL  Baldwin County                              4.0
# 4  8       1005    AL  Barbour County                              6.0
#
#    2003 Urban Influence Code  2013 Rural-urban Continuum Code  \
# 0                        NaN                              NaN
# 1                        NaN                              NaN
# 2                        2.0                              2.0
# 3                        5.0                              3.0
# 4                        6.0                              6.0
#
#    2013 Urban Influence Code  Less than a high school diploma, 1970  \
# 0                        NaN                             52373312.0
# ...

# %%
#To understand the data
educ_data_frame.describe()
# Out:
#                  3     FIPS Code  2003 Rural-urban Continuum Code  \
# count  3283.000000   3283.000000                      3221.000000
# mean   1645.000000  31308.242766                         5.057125
# std     947.864793  16343.477485                         2.701247
# min       4.000000      0.000000                         1.000000
# 25%     824.500000  19016.000000                         3.000000
# 50%    1645.000000  30017.000000                         6.000000
# 75%    2465.500000  46100.000000                         7.000000
# max    3286.000000  72153.000000                         9.000000
#
#        2003 Urban Influence Code  2013 Rural-urban Continuum Code  \
# count                3221.000000                      3221.000000
# mean                    5.371624                         4.936976
# std                     3.483776                         2.724413
# min                     1.000000                         1.000000
# ...

# %%
#Visualize particular column look out for extreme values
educ_data_frame["Percent of adults with a bachelor's degree or higher, 2013-17"].hist(bins=50)
